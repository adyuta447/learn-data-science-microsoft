# %%
import pandas as pd
data = {'pet': [
    'dog', 'dog', 'cat', 'cat', 'bird', 'bird'
] * 8 + ['bird', 'cat']}

df = pd.DataFrame(data)
print(df.head(10))
# Out:
#     pet
# 0   dog
# 1   dog
# 2   cat
# 3   cat
# 4  bird
# 5  bird
# 6   dog
# 7   dog
# 8   cat
# 9   cat
