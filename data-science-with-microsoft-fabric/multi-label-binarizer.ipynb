# %%
import pandas as pd
data = {
    'food': ['pasta', 'burger', 'ice cream', 'salad'],
    'category': ['Italian|Fine dining', 'American|Fast Food', 'Dessert', 'Healthy']
}

restaurant_df = pd.DataFrame(data)
print(restaurant_df)
# Out:
#         food             category
# 0      pasta  Italian|Fine dining
# 1     burger   American|Fast Food
# 2  ice cream              Dessert
# 3      salad              Healthy
